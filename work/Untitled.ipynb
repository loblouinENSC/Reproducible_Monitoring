# %%
# %run visualize_toilet
# Out:
# /root/linux_documents/reproducibilitymonitoring/work/visualize_toilet.py:48: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   out = activity.resample('M').agg({"activity_count":'sum', "duration":['mean', 'sem']})
# /root/linux_documents/reproducibilitymonitoring/work/visualize_toilet.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   activity_dataset = pd.read_csv(out_file, delimiter =';', decimal=",",
# /root/linux_documents/reproducibilitymonitoring/work/visualize_toilet.py:67: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   idx = pd.date_range('2017-01-31', '2017-12-31', freq='m')
# ...

# %%
# %run visualize_sleep_quiet
# Out:
# /root/linux_documents/reproducibilitymonitoring/work/visualize_sleep_quiet.py:38: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   sleep.resample('M').agg({"durationHr":['mean', 'sem']})
# /root/linux_documents/reproducibilitymonitoring/work/visualize_sleep_quiet.py:40: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   outSleep = sleep.resample('M').agg({"durationHr":['mean', 'sem']})
# /root/linux_documents/reproducibilitymonitoring/work/visualize_sleep_quiet.py:45: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   rest = pd.read_csv(out, delimiter =';', decimal=",",
# ...

# %%
# %run visualize_toilet
# Out:
# /root/linux_documents/reproducibilitymonitoring/work/visualize_toilet.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   activity_dataset = pd.read_csv(out_file, delimiter =';', decimal=",",
# /root/linux_documents/reproducibilitymonitoring/work/visualize_toilet.py:75: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   activity_dataset = pd.read_csv(out_file, delimiter =';', decimal=",",
# /root/linux_documents/reproducibilitymonitoring/work/visualize_toilet.py:95: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'ME' instead.
#   idx = pd.date_range('2017-01-31', '2017-12-31', freq='m')
